# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd
from scipy.integrate import solve_ivp

# Labels do eixo horizontal considerando o período de início de fim da coleta de dados.
lista = []
for ano in range(2020,2023,1):
    for mes in range(1,13,1):
        if mes < 10:
            lista.append(f'{ano}/0{mes}/01')
        else:
            lista.append(f'{ano}/{mes}/01')
labels_lista = lista[3:27]
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/compat/_optional.py:161: UserWarning: Pandas requires version '1.3.1' or newer of 'bottleneck' (version '1.2.1' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Niterói

# %%
url = 'https://raw.githubusercontent.com/isplay/projeto_propagacao_epidemias/main/csv/Infectados_em_Niter%C3%B3i.csv'
dados0 = pd.read_csv(url, index_col=0)

população_niteroi = 515317

dados0_y_niteroi = dados0['Casos'].to_numpy()/população_niteroi
dados0_x_niteroi = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(dados0_x_niteroi, dados0_y_niteroi)
ax.grid(True)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45)
ax.set_xlim(['2022/01/01','2022/03/01'])
plt.title('Infectados na cidade Niterói')
#plt.savefig('niteroi.png')
# Out:
# Text(0.5, 1.0, 'Infectados na cidade Niterói')

# %% [markdown]
# #

# %%
dados = pd.read_csv('/home/isplay/Área de Trabalho/2020_BR_Region_Mobility_Report.csv', index_col=3)
dados
# Out:
# /tmp/ipykernel_7324/242417883.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('/home/isplay/Área de Trabalho/2020_BR_Region_Mobility_Report.csv', index_col=3)
#                country_region_code country_region        sub_region_1  \
# sub_region_2
# NaN                             BR         Brazil                 NaN
# NaN                             BR         Brazil                 NaN
# NaN                             BR         Brazil                 NaN
# NaN                             BR         Brazil                 NaN
# NaN                             BR         Brazil                 NaN
# ...                            ...            ...                 ...
# Tocantinópolis                  BR         Brazil  State of Tocantins
# Tocantinópolis                  BR         Brazil  State of Tocantins
# Tocantinópolis                  BR         Brazil  State of Tocantins
# ...

# %%
dados = pd.read_csv('/home/isplay/Área de Trabalho/2020_BR_Region_Mobility_Report.csv', index_col=3)

rj = dados.loc['Rio de Janeiro']

rj = rj.drop(columns=['country_region_code','country_region','sub_region_1','metro_area','iso_3166_2_code','census_fips_code','place_id'])

rj = rj.set_index('date')

rj.plot(figsize=(15,10))
# Out:
# /tmp/ipykernel_7324/4034845786.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('/home/isplay/Área de Trabalho/2020_BR_Region_Mobility_Report.csv', index_col=3)
# <AxesSubplot:xlabel='date'>

# %%
dados = pd.read_csv('/home/isplay/Área de Trabalho/2020_BR_Region_Mobility_Report.csv', index_col=3)

niteroi = dados.loc['Niterói']

niteroi = niteroi.drop(columns=['country_region_code','country_region','sub_region_1','metro_area','iso_3166_2_code','census_fips_code','place_id'])

niteroi = niteroi.set_index('date')

niteroi.plot(figsize=(15,10))
# Out:
# /tmp/ipykernel_2356/1622066615.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('/home/isplay/Área de Trabalho/2020_BR_Region_Mobility_Report.csv', index_col=3)
# <AxesSubplot:xlabel='date'>

# %%
x = niteroi.index.to_numpy()

for i in range(len(x)):
    a = x[i]
    b = a.split('-')
    c = '/'.join(b)
    x[i] = c
# Out:
# array(['2020/02/15', '2020/02/16', '2020/02/17', '2020/02/18',
#        '2020/02/19', '2020/02/20', '2020/02/21', '2020/02/22',
#        '2020/02/23', '2020/02/24', '2020/02/25', '2020/02/26',
#        '2020/02/27', '2020/02/28', '2020/02/29', '2020/03/01',
#        '2020/03/02', '2020/03/03', '2020/03/04', '2020/03/05',
#        '2020/03/06', '2020/03/07', '2020/03/08', '2020/03/09',
#        '2020/03/10', '2020/03/11', '2020/03/12', '2020/03/13',
#        '2020/03/14', '2020/03/15', '2020/03/16', '2020/03/17',
#        '2020/03/18', '2020/03/19', '2020/03/20', '2020/03/21',
#        '2020/03/22', '2020/03/23', '2020/03/24', '2020/03/25',
#        '2020/03/26', '2020/03/27', '2020/03/28', '2020/03/29',
#        '2020/03/30', '2020/03/31', '2020/04/01', '2020/04/02',
#        '2020/04/03', '2020/04/04', '2020/04/05', '2020/04/06',
#        '2020/04/07', '2020/04/08', '2020/04/09', '2020/04/10',
#        '2020/04/11', '2020/04/12', '2020/04/13', '2020/04/14',
# ...

# %%
retail_and_recreation_percent_change_from_baseline = niteroi['retail_and_recreation_percent_change_from_baseline'].to_numpy()
grocery_and_pharmacy_percent_change_from_baseline = niteroi['grocery_and_pharmacy_percent_change_from_baseline'].to_numpy()
parks_percent_change_from_baseline = niteroi['parks_percent_change_from_baseline'].to_numpy()
transit_stations_percent_change_from_baseline = niteroi['transit_stations_percent_change_from_baseline'].to_numpy()
workplaces_percent_change_from_baseline = niteroi['workplaces_percent_change_from_baseline'].to_numpy()
residential_percent_change_from_baseline = niteroi['residential_percent_change_from_baseline'].to_numpy()
date = niteroi.index.to_numpy()


fig, ax = plt.subplots(figsize=(15,10))

ax.plot(date, residential_percent_change_from_baseline, label='residential_percent_change_from_baseline')
ax.plot(date, grocery_and_pharmacy_percent_change_from_baseline, label='grocery_and_pharmacy_percent_change_from_baseline')
ax.plot(date, parks_percent_change_from_baseline, label='parks_percent_change_from_baseline')
ax.plot(date, transit_stations_percent_change_from_baseline, label='transit_stations_percent_change_from_baseline')
ax.plot(date, workplaces_percent_change_from_baseline, label='workplaces_percent_change_from_baseline')
ax.plot(date, residential_percent_change_from_baseline, label='residential_percent_change_from_baseline')
ax.axhline(y=0, color='k')

bx = ax.twinx()

bx.plot(dados0_x_niteroi, dados0_y_niteroi, label='Casos confirmados em Niterói')

ax.legend(frameon=False)
ax.grid(True)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45)
ax.set_xlim(['2020/02/01','2020/12/01'])
ax.set_ylim([-100,100])

#plt.title('Infectados na cidade Niterói')
#plt.savefig('niteroi.png')
# Out:
# (-100.0, 100.0)

# %%
line1 = plt.plot(tempo,divorcios,'b-o')
plt.ylim(4,5.2)
plt.ylabel('Divorcios por 100 mil')
plt.xlabel('Anos')
plt.twinx()
line2 = plt.plot(tempo,margarina,'r-v')
plt.ylabel('Consumo de Margarina [lb]')
lines = line1 + line2
legendas = ['Divorcios','Consumo de Margarina']
plt.legend(lines, legendas, frameon=False)
