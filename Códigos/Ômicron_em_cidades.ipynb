# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd

# Labels do eixo horizontal considerando o período de início de fim da coleta de dados.
lista = []
for ano in range(2020,2023,1):
    for mes in range(1,13,1):
        if mes < 10:
            lista.append(f'{ano}/0{mes}/01')
        else:
            lista.append(f'{ano}/{mes}/01')
labels_lista = lista[3:28]

# %% [markdown]
# # Fonte dos dados:
# Dados do Estado do Rio de Janeiro:
# <http://sistemas.saude.rj.gov.br/tabnetbd/dhx.exe?covid19/esus_sivep.def>
#
# Base de Datos COVID-19 (Brasil): https://covid.saude.gov.br/ e  https://brasil.io/dataset/covid19/caso_full/
#
# IDH de cidades ao redor do mundo:
# <https://globaldatalab.org/shdi/shdi/?levels=1%2B4&interpolation=1&extrapolation=0&nearest_real=0>
#
# COVID-19 Data Repository by the Center for Systems Science and Engineering (CSSE) at Johns Hopkins University: <https://github.com/CSSEGISandData/COVID-19>
#
# Base de Datos COVID-19 (Chile): https://www.minciencia.gob.cl/covid19/ e https://github.com/MinCiencia/Datos-COVID19
#
# Base de Datos COVID-19 (USA): https://usafacts.org/visualizations/coronavirus-covid-19-spread-map
#
# Casos confirmados em Buenos Aires - Argentina: <https://data.buenosaires.gob.ar/dataset/casos-covid-19>
#
# Casos confirmados em Tokyo - Japão: <https://catalog.data.metro.tokyo.lg.jp/dataset/t000010d0000000068> e <https://covid19.mhlw.go.jp/en/>
#
# França: https://data.education.gouv.fr/explore/dataset/fr-en-situation_nationale_covid/export/?sort=date e https://www.data.gouv.fr/fr/datasets/synthese-des-indicateurs-de-suivi-de-lepidemie-covid-19/
#
# Espanha: <https://datos.comunidad.madrid/catalogo/dataset/covid19_tia_muni_y_distritos>

# %% [markdown]
# # Niterói - Brasil

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Infectados_em_Niterói.csv', index_col=0)

população_niteroi = 516981
# Fonte: <https://www.ibge.gov.br/cidades-e-estados/rj/niteroi.html> 28/04/2022

dados0_y_niteroi = dados0['Niteroi'].to_numpy()/população_niteroi
dados0_x_niteroi = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(dados0_x_niteroi, dados0_y_niteroi, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45)
plt.title(f'Casos confirmados na cidade Niterói; População de {população_niteroi} habitantes.')
ax.set_xlim(['2021/12/01','2022/03/01'])
# Out:
# (626.0, 716.0)

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Infectados_em_Niterói.csv', index_col=0)

população_niteroi = 516981
# Fonte: <https://www.ibge.gov.br/cidades-e-estados/rj/niteroi.html> 28/04/2022

dados0_y_niteroi = dados0['Niteroi'].to_numpy()/população_niteroi
dados0_x_niteroi = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(dados0_x_niteroi, dados0_y_niteroi, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45)
plt.title(f'Niterói; População de {população_niteroi} habitantes.')
ax.set_xlim(['2021/12/01','2022/05/01'])
plt.savefig('Niterói.pdf')

# %% [markdown]
# # Buenos Aires - Argentina

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/buenos_aires_casos.csv', index_col=1)

população_ba = 2891082
# Fonte: https://pt.wikipedia.org/wiki/Buenos_Aires - 28/04/2022

dados0_y_ba = dados0['Casos confirmados'].to_numpy()/população_ba
dados0_x_ba = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(dados0_x_ba, dados0_y_ba, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45)
plt.title(f'Buenos Aires; População de {população_ba} habitantes.')
# Out:
# Text(0.5, 1.0, 'Buenos Aires; População de 2891082 habitantes.')

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/buenos_aires_casos.csv', index_col=1)

população_ba = 2891082
# Fonte: https://pt.wikipedia.org/wiki/Buenos_Aires - 28/04/2022

dados0_y_ba = dados0['Casos confirmados'].to_numpy()/população_ba
dados0_x_ba = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(dados0_x_ba, dados0_y_ba, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45)
plt.title(f'Buenos Aires; População de {população_ba} habitantes.')
ax.set_xlim(['2021/12/01','2022/05/01'])
plt.savefig('Buenos_Aires.pdf')

# %% [markdown]
# # Região Metropolitana de Santiago - Chile

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Região Metropolitana de Santiago(Chile).csv', index_col=0)

população_metropolitana = 7003122
# Fonte: https://pt.wikipedia.org/wiki/Santiago_(regi%C3%A3o_metropolitana) - 28/04/2022

dados0_y_Metropolitana = dados0['Metropolitana'].to_numpy()/população_metropolitana
dados0_x_Metropolitana = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(dados0_x_Metropolitana, dados0_y_Metropolitana, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45) 
plt.title(f'Região Metropolitana de Santiago(Chile); População de {população_metropolitana} habitantes.')
# Out:
# Text(0.5, 1.0, 'Região Metropolitana de Santiago(Chile); População de 7003122 habitantes.')

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Região Metropolitana de Santiago(Chile).csv', index_col=0)

população_metropolitana = 7003122
# Fonte: https://pt.wikipedia.org/wiki/Santiago_(regi%C3%A3o_metropolitana) - 28/04/2022

dados0_y_Metropolitana = dados0['Metropolitana'].to_numpy()/população_metropolitana
dados0_x_Metropolitana = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(dados0_x_Metropolitana, dados0_y_Metropolitana, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
plt.title(f'Região Metropolitana de Santiago(Chile); População de {população_metropolitana} habitantes.')
ax.set_xlim(['2021/12/01','2022/05/01'])
plt.savefig('Metropolitana.pdf')

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Região Metropolitana de Santiago(Chile).csv', index_col=0)

população_metropolitana = 7003122
# Fonte: https://pt.wikipedia.org/wiki/Santiago_(regi%C3%A3o_metropolitana) - 28/04/2022

dados0_y_Metropolitana = dados0['Metropolitana'].to_numpy()/população_metropolitana
dados0_x_Metropolitana = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(dados0_x_Metropolitana, dados0_y_Metropolitana, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)

plt.yscale("log")

ax.set_xticks(labels_lista)
plt.title(f'Região Metropolitana de Santiago(Chile); População de {população_metropolitana} habitantes.')
ax.set_xlim(['2021/12/01','2022/05/01'])
plt.savefig('Metropolitana.pdf')

# %% [markdown]
# # Tokyo distrito - Japão

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Tokyo_Japan_Data_Covid_19.csv', index_col=0)

população_Tokyo = 13503810
# Fonte: https://pt.wikipedia.org/wiki/T%C3%B3quio - 29/04/2022

dados0_y_Tokyo = dados0['Tokyo'].to_numpy()/população_Tokyo
dados0_x_Tokyo = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(dados0_x_Tokyo, dados0_y_Tokyo, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45) 
plt.title(f'Tóquio - Japão; População de {população_Tokyo} habitantes.')
# Out:
# Text(0.5, 1.0, 'Tóquio - Japão; População de 13503810 habitantes.')

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Tokyo_Japan_Data_Covid_19.csv', index_col=0)

população_Tokyo = 13503810
# Fonte: https://pt.wikipedia.org/wiki/T%C3%B3quio - 29/04/2022

dados0_y_Tokyo = dados0['Tokyo'].to_numpy()/população_Tokyo
dados0_x_Tokyo = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(dados0_x_Tokyo, dados0_y_Tokyo, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
plt.title(f'Casos confirmados em Tóquio - Distrito - Japão; População de {população_Tokyo} habitantes.')
ax.set_xlim(['2021/12/01','2022/05/01'])
plt.savefig('Tóquio.pdf')

# %% [markdown]
# # Paris - France

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Paris_França_Casos_confirmados.csv', index_col=0)

população_Paris = 2148271
# Fonte: https://pt.wikipedia.org/wiki/Paris - 29/04/2022

dados0_y_Paris = dados0['pos'].to_numpy()/população_Paris
dados0_x_Paris = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(dados0_x_Paris, dados0_y_Paris, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45) 
plt.title(f'Paris(França); População de {população_Paris} habitantes.')
# Out:
# Text(0.5, 1.0, 'Paris(França); População de 2148271 habitantes.')

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Paris_França_Casos_confirmados.csv', index_col=0)

população_Paris = 2148271
# Fonte: https://pt.wikipedia.org/wiki/Paris - 29/04/2022

dados0_y_Paris = dados0['pos'].to_numpy()/população_Paris
dados0_x_Paris = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(dados0_x_Paris, dados0_y_Paris, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
plt.title(f'Paris(França); População de {população_Paris} habitantes.')
ax.set_xlim(['2021/12/01','2022/05/01'])
plt.savefig('Paris.pdf')

# %% [markdown]
# # New York County- USA

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/New_York_County_USA_Data_Covid.csv', index_col=0)

população_NYC = 8804190 
# Fonte: hhttps://pt.wikipedia.org/wiki/Nova_Iorque - 29/04/2022

dados0_y_NYC = dados0['New York County'].to_numpy()/população_NYC
dados0_x_NYC = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(dados0_x_NYC, dados0_y_NYC, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45) 
plt.title(f'Casos confirmados no município New York (USA); População de {população_NYC} habitantes.')
# Out:
# Text(0.5, 1.0, 'Casos confirmados no município New York (USA); População de 8804190 habitantes.')

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/New_York_County_USA_Data_Covid.csv', index_col=0)

população_NYC = 8804190 
# Fonte: hhttps://pt.wikipedia.org/wiki/Nova_Iorque - 29/04/2022

dados0_y_NYC = dados0['New York County'].to_numpy()/população_NYC
dados0_x_NYC = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(dados0_x_NYC, dados0_y_NYC, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45) 
plt.title(f'Casos confirmados no município New York (USA); População de {população_NYC} habitantes.')
ax.set_xlim(['2021/12/01','2022/05/01'])
plt.savefig('New York County.pdf')

# %% [markdown]
# # Madrid - Espanha

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Madrid-Centro_Espanha_Casos_confirmados.csv', index_col=0)

população_mc = 149718 
# Fonte: https://pt.wikipedia.org/wiki/Centro_(distrito_de_Madrid) - 29/04/2022

dados0_y_mc = dados0['Casos confirmados'].to_numpy()/população_mc
dados0_x_mc = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(dados0_x_mc, dados0_y_mc, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45) 
plt.title(f'Casos confirmados Centro (distrito de Madrid)- Espanha; População de {população_mc} habitantes.')
# Out:
# Text(0.5, 1.0, 'Casos confirmados Centro (distrito de Madrid)- Espanha; População de 149718 habitantes.')

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv/Madrid-Centro_Espanha_Casos_confirmados.csv', index_col=0)

população_mc = 149718 
# Fonte: https://pt.wikipedia.org/wiki/Centro_(distrito_de_Madrid) - 29/04/2022

dados0_y_mc = dados0['Casos confirmados'].to_numpy()/população_mc
dados0_x_mc = dados0.index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(dados0_x_mc, dados0_y_mc, label='Casos confirmados')
ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
fig.autofmt_xdate(rotation=45) 
plt.title(f'Casos confirmados Centro (distrito de Madrid)- Espanha; População de {população_mc} habitantes.')
ax.set_xlim(['2021/06/01','2022/03/01'])
plt.savefig('Madrid-Centro.pdf')

# %% [markdown]
# # Unindo os gráficos

# %%
fig, ax = plt.subplots(figsize=(15,8))

ax.plot(dados0_x_niteroi, dados0_y_niteroi,'--', label='Niterói')
ax.plot(dados0_x_Metropolitana, dados0_y_Metropolitana,'--', label='Região Metropolitana de Santiago')
ax.plot(dados0_x_Tokyo, dados0_y_Tokyo, label='Tokyo')
ax.plot(dados0_x_NYC, dados0_y_NYC, label='Município de New York')
ax.plot(dados0_x_mc, dados0_y_mc, label=' Centro (Distrito de Madrid)')
ax.plot(dados0_x_Paris, dados0_y_Paris, label='Paris')
ax.plot(dados0_x_ba, dados0_y_ba, label='Buenos Aires')

plt.yscale("log")


#ax.axvline(x='2021/12/20')

ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
plt.title(f'Casos confirmados de Covid-19 ao redor do mundo.')
#ax.set_xlim(['2021/12/01','2022/04/01'])
# Out:
# Text(0.5, 1.0, 'Casos confirmados de Covid-19 ao redor do mundo.')

# %%
fig, ax = plt.subplots(figsize=(15,8))

ax.scatter(dados0_x_Paris, dados0_y_Paris, label='Paris')
ax.scatter(dados0_x_ba, dados0_y_ba, label='Buenos Aires')

ax.grid(True)
ax.set_ylabel('Densidade populpopacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
ax.set_yticks([0.0001,0.0010,0.0020])

plt.title(f'Casos confirmados de Covid-19 ao redor do mundo.')
ax.set_xlim(['2021/12/01','2022/03/01'])
# Out:
# (567.0, 657.0)

# %%
fig, ax = plt.subplots(figsize=(15,8))

ax.plot(dados0_x_niteroi, dados0_y_niteroi,'--', label='Niterói')
ax.plot(dados0_x_Metropolitana, dados0_y_Metropolitana,'--', label='Região Metropolitana de Santiago')
ax.plot(dados0_x_Tokyo, dados0_y_Tokyo, label='Tokyo')
ax.plot(dados0_x_NYC, dados0_y_NYC,'-o', label='Município de New York')
ax.plot(dados0_x_mc, dados0_y_mc, label=' Centro (Distrito de Madrid)')
ax.plot(dados0_x_Paris, dados0_y_Paris, label='Paris')
ax.plot(dados0_x_ba, dados0_y_ba, '-*',label='Buenos Aires')

plt.yscale("log")

#fig.autofmt_xdate(rotation=45)
ax.grid(True)
ax.set_ylabel('Densidade popacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
plt.title(f'Casos confirmados de Covid-19')
ax.set_xlim(['2021/12/01','2022/03/01'])
#ax.set_ylim([0,0.0005])
# Out:
# (626.0, 716.0)

# %%
Remover os zeros
Fazendo uma média dos termos ao redor

# %%
fig, ax = plt.subplots(figsize=(15,10),dpi=300)

ax.plot(dados0_x_niteroi, dados0_y_niteroi,'--', label='Niterói - Brasil')
ax.plot(dados0_x_Metropolitana, dados0_y_Metropolitana,'--', label='Região Metropolitana de Santiago - Chile')
ax.plot(dados0_x_Tokyo, dados0_y_Tokyo,'--', label='Tóquio (Distrito) - Japão')
ax.plot(dados0_x_NYC, dados0_y_NYC,'--', label='New York County - EUA')
ax.plot(dados0_x_mc, dados0_y_mc, '--', label='Centro (Distrito de Madrid) - Espanha')
ax.plot(dados0_x_Paris, dados0_y_Paris,'--', label='Paris - França')
ax.plot(dados0_x_ba, dados0_y_ba, '--',label='Buenos Aires - Argentina')

plt.yscale("log")

#fig.autofmt_xdate(rotation=45)
ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
plt.title(f'Casos confirmados de Covid-19')
ax.set_xlim(['2021/12/01','2022/03/01'])
#ax.set_ylim([0,0.0005])
texto = ['Fontes dos dados:'+'\n'+
         'Niterói: <http://sistemas.saude.rj.gov.br/>'+'                                    '+
         'Região Metropolitana de Santiago: <https://www.minciencia.gob.cl/>'+'\n'+
        'Tóquio (distrito): <https://catalog.data.metro.tokyo.lg.jp/>'+'           '+
        'New York County: <https://usafacts.org/>'+'\n'+
        'Centro(Distrito de Madrid): <https://datos.comunidad.madrid/>'+'   '+
        'Paris: <https://data.education.gouv.fr/>'+'\n'+
        'Buenos Aires: <https://data.buenosaires.gob.ar/>']

ax.text(0.01, -0.145, texto[0],transform=ax.transAxes)
plt.savefig('Escala_logaritmica_ômicron.pdf')

# %%
fig, ax = plt.subplots(figsize=(15,10),dpi=300)

ax.plot(dados0_x_niteroi, dados0_y_niteroi,'--', label='Niterói - Brasil')
ax.plot(dados0_x_Paris, dados0_y_Paris,'--', label='Paris - França')
ax.plot(dados0_x_ba, dados0_y_ba, '--',label='Buenos Aires - Argentina')
ax.plot(dados0_x_NYC, dados0_y_NYC,'--', label='New York County - EUA')

plt.yscale("log")

#fig.autofmt_xdate(rotation=45)
ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
plt.title(f'Casos confirmados de Covid-19')
ax.set_xlim(['2021/12/01','2022/03/01'])
#ax.set_ylim([0,0.0005])
plt.savefig('Escala_log_linear_1.pdf')

# %%
fig, ax = plt.subplots(figsize=(15,10),dpi=300)

ax.plot(dados0_x_Metropolitana, dados0_y_Metropolitana,'--', label='Região Metropolitana de Santiago - Chile')
ax.plot(dados0_x_Tokyo, dados0_y_Tokyo,'--', label='Tóquio (Distrito) - Japão')
ax.plot(dados0_x_mc, dados0_y_mc, '--', label='Centro (Distrito de Madrid) - Espanha')

plt.yscale("log")

#fig.autofmt_xdate(rotation=45)
ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.legend(frameon=False)
ax.set_xticks(labels_lista)
plt.title(f'Casos confirmados de Covid-19')
ax.set_xlim(['2021/12/01','2022/05/01'])
#ax.set_ylim([0,0.0005])
plt.savefig('Escala_log_linear_2.pdf')
