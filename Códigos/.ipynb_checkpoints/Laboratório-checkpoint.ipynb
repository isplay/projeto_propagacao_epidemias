# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd
from scipy.integrate import solve_ivp, odeint

# %%
# SEIR.

# sub de subida.
# des de descida.

R0 = 1.3
t_p1 = 30
t_p2 = 52
valor = 0

def sir(t, y):
    s, i, c, r = y
    dsdt = - R0 * s * i
    dcdt = -np.tanh((t-t_1))*valor/2 + np.tanh((t-t_2))*valor/2
    didt = R0 * s * i - i + np.tanh(t-t_p1)*valor/2 - np.tanh(t-t_p2)*valor/2
    drdt = i
    return dsdt, didt, dcdt, drdt

t0, t = 0, 1000
i0 = 1e-10
r0 = 0
c0 = 0.1
s0 = 1 - i0 - r0 - c0

t_discreto = np.linspace(t0,t,t)

res = solve_ivp(sir, (t0, t), y0=[s0, i0, c0, r0], t_eval=t_discreto, method='LSODA')


fig, ax = plt.subplots(figsize=(10,8))
ax.plot(res.t, res.y[1],'r')

# %%
# SEIR.


R0 = 1.5
valor = .5
t_1 = 100
t_2 = 250

def sir(t, y):
    s, i, r = y
    dsdt = - R0 * s * i
    didt = R0 * s * i - i + np.tanh((t-t_1))*valor/2 - np.tanh((t-t_2))*valor/2
    drdt = i
    return dsdt, didt, drdt

t0, t = 0, 100
i0 = 1e-10
r0 = 0
s0 = 1 - i0 - r0 

t_discreto = np.linspace(t0,t,t)

res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=t_discreto, method='LSODA')


fig, ax = plt.subplots(figsize=(10,8))
ax.plot(res.t, res.y[1],'r')

# %%
t = np.linspace(0,20)
valor = 0.1
f = -(np.tanh(t-6) - np.tanh(t-15))*valor/2
plt.plot(t,f)

# %%
t = np.linspace(0,100)
s = 0.9
R = R0 * s * i - i + A*np.tanh(t-t_m)*c*i - A*np.tanh(t-t_m2)*c*i
plt.plot(t, R)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [281], in <cell line: 2>()
#       1 t = np.linspace(0,100)
# ----> 2 R = R0 * s * i - i + A*np.tanh(t-t_m)*c*i - A*np.tanh(t-t_m2)*c*i
#       3 plt.plot(t, R)
#
# NameError: name 's' is not defined

# %%
def sir(t, y):
    s, i, r = y
    dsdt = - R0 * s * i
    didt = R0 * s * i - i + ((R0_s - (R0_s+R0_f)/2)*np.tanh(t - 7) + (R0_s+R0_f)/2 - (R0_s - (R0_s+R0_d)/2)*np.tanh(t - 20) + (R0_s+R0_d)/2 - R0_s)*i
    drdt = i
    return dsdt, didt, drdt

# %%
t = np.linspace(0,40)

R0_f = 1.5
R0_s = 1.8
R0_d = 1.5

M = (R0_s+R0_d)/2
N = (R0_s+R0_f)/2
A = R0_s - M
B = R0_s - N

R0 = A*np.tanh(t - 7) + N - B*np.tanh(t - 20) + M - R0_s

plt.plot(t, R0)
R0
# Out:
# array([1.50000025, 1.50000128, 1.50000653, 1.50003343, 1.50017099,
#        1.50087296, 1.50441442, 1.52130001, 1.58434433, 1.70004869,
#        1.77331518, 1.79438355, 1.7988857 , 1.7997816 , 1.79995729,
#        1.7999916 , 1.79999809, 1.79999824, 1.79999255, 1.79996221,
#        1.79980675, 1.7990137 , 1.79502009, 1.77614604, 1.7080368 ,
#        1.5919632 , 1.52385396, 1.50497991, 1.5009863 , 1.50019324,
#        1.50003778, 1.50000738, 1.50000144, 1.50000028, 1.50000006,
#        1.50000001, 1.5       , 1.5       , 1.5       , 1.5       ,
#        1.5       , 1.5       , 1.5       , 1.5       , 1.5       ,
#        1.5       , 1.5       , 1.5       , 1.5       , 1.5       ])

# %%
t = np.linspace(0,1000)
I0 = 1e-5
I = I0*np.exp((R0-1)*t)
plt.plot(t,I)

# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd

# %%
# Labels do eixo horizontal considerando o período de início de fim da coleta de dados.
lista = []
for ano in range(2020,2023,1):
    for mes in range(1,13,1):
        if mes < 10:
            lista.append(f'{ano}/0{mes}/01')
        else:
            lista.append(f'{ano}/{mes}/01')
labels_lista = lista[3:28]

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/Infectados_em_Niterói.csv', index_col=0)
dados0
# Out:
#                      Niteroi  Ordem
# Data da notificacao
# 2020/03/15               3.0      0
# 2020/03/16               3.0      1
# 2020/03/17               1.0      2
# 2020/03/18               5.0      3
# 2020/03/19               5.0      4
# ...                      ...    ...
# 2022/04/12             126.0    758
# 2022/04/13              62.0    759
# 2022/04/14              29.0    760
# 2022/04/15              17.0    761
# 2022/04/16               6.0    762
#
# [763 rows x 2 columns]

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/Infectados_em_Niterói.csv', index_col=0)

população_niteroi = 516981
# Fonte: <https://www.ibge.gov.br/cidades-e-estados/rj/niteroi.html> 28/04/2022

dados0_y_niteroi = dados0['Niteroi'].to_numpy()/população_niteroi
dados0_x_niteroi = dados0['Ordem'].to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(dados0_x_niteroi, dados0_y_niteroi, label='Casos confirmados')

plt.xscale('log')
plt.yscale('log')

ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.legend(frameon=False)
#ax.set_xticks(labels_lista)
plt.title(f'Casos confirmados na cidade Niterói; População de {população_niteroi} habitantes.')
#ax.set_xlim(['630','750'])
# Out:
# Text(0.5, 1.0, 'Casos confirmados na cidade Niterói; População de 516981 habitantes.')

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/Infectados_em_Niterói.csv', index_col=0)

população_niteroi = 516981
# Fonte: <https://www.ibge.gov.br/cidades-e-estados/rj/niteroi.html> 28/04/2022

dados0_y_niteroi = dados0['Niteroi'].to_numpy()/população_niteroi
dados0_x_niteroi = dados0['Ordem'].to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(dados0_x_niteroi, dados0_y_niteroi, label='Casos confirmados')

plt.yscale('log')
plt.xscale('log')

ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.legend(frameon=False)
#ax.set_xticks(labels_lista)
plt.title(f'Casos confirmados na cidade Niterói; População de {população_niteroi} habitantes.')
ax.set_xlim([650,750])
# Out:
# (650, 750)

# %%
x = np.arange(1,100)
y = np.exp(x)
plt.plot(x,y)
plt.yscale('log')
plt.xscale('log')

# %%
x = np.arange(1,100,10)
y = np.exp(x)
plt.plot(x,y)

# %%
print(x)
print(x*x)
# Out:
# [   1.  112.  223.  334.  445.  556.  667.  778.  889. 1000.]
# [1.00000e+00 1.25440e+04 4.97290e+04 1.11556e+05 1.98025e+05 3.09136e+05
#  4.44889e+05 6.05284e+05 7.90321e+05 1.00000e+06]

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv_dados_limpos/Rio_de_Janeiro_cidade_limpos.csv')

população_rio = 6775561
# Fonte: <https://www.ibge.gov.br/cidades-e-estados/rj/rio-de-janeiro.html> 06/05/2022

dados0_y_rio = dados0['Rio de Janeiro'].loc[678:730].to_numpy()/população_rio
dados0_x_rio = dados0.loc[678:730].index.to_numpy()

fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(dados0_x_rio, dados0_y_rio, label='Casos confirmados')
plt.yscale("log")
ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.legend(frameon=False)
fig.autofmt_xdate(rotation=45)
ax.set_xticks([])
plt.title(f'Casos confirmados no município Rio de Janeiro; População de {população_rio} habitantes.')
#ax.set_xlim(['2021/12/01','2022/05/01'])
# Out:
# Text(0.5, 1.0, 'Casos confirmados no município Rio de Janeiro; População de 6775561 habitantes.')

# %%
dados0['Rio de Janeiro'].loc['2021/12/20':'2022/02/15']
# Out:
# 63

# %%
x = np.arange(10)
y = np.cos(x)
plt.plot(x,y)
plt.xticks([0,2,4,6,8], labels=['a','b','c','d','e'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f1143cfbd60>,
# ...
#  [Text(0, 0, 'a'),
#   Text(2, 0, 'b'),
#   Text(4, 0, 'c'),
#   Text(6, 0, 'd'),
#   Text(8, 0, 'e')])

# %%
coef1 = np.polynomial.polynomial.Polynomial.fit(arr_t_des,arr_des, 1)

a_des, b_des = coef1.convert().coef

lista_coef_R0_descida.append([b_des,R0])

# %%
dados0
# Out:
#             Rio de Janeiro  Unnamed: 2
# Datas
# 2020/01/04             2.0         NaN
# 2020/01/06             1.0         NaN
# 2020/01/09             2.0         NaN
# 2020/01/11             2.0         NaN
# 2020/01/12             2.0         NaN
# ...                    ...         ...
# 2022/05/01            27.0         NaN
# 2022/05/02           272.0         NaN
# 2022/05/03           262.0         NaN
# 2022/05/04           202.0         NaN
# 2022/05/05             1.0         NaN
#
# [813 rows x 2 columns]

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv_dados_limpos/Rio_de_Janeiro_cidade_limpos.csv', index_col=3)
dados0

arr1 = dados0.index.to_numpy()
arr2 = dados0['Rio de Janeiro'].to_numpy()

plt.plot(arr1,arr2)
plt.xticks([475], labels=[dados0.loc[475]['Datas']])
# Out:
# ([<matplotlib.axis.XTick at 0x7f113e312a70>], [Text(475, 0, '2021/06/01')])

# %%
dados0.loc[475]['Datas']
# Out:
# '2021/06/01'

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/csv_dados_limpos/Rio_de_Janeiro_cidade_limpos.csv')
dados0.loc[0]
# Out:
# Datas             2020/01/04
# Rio de Janeiro           2.0
# Dados salvos             NaN
# Numeração                  1
# Name: 0, dtype: object

# %%
dados1 = dados0.set_index('Numeração')
# Out:
#                 Datas  Rio de Janeiro  Dados salvos
# Numeração
# 1          2020/01/04             2.0           NaN
# 2          2020/01/06             1.0           NaN
# 3          2020/01/09             2.0           NaN
# 4          2020/01/11             2.0           NaN
# 5          2020/01/12             2.0           NaN
# ...               ...             ...           ...
# 809        2022/05/01            27.0           NaN
# 810        2022/05/02           272.0           NaN
# 811        2022/05/03           262.0           NaN
# 812        2022/05/04           202.0           NaN
# 813        2022/05/05             1.0           NaN
#
# [813 rows x 3 columns]

# %%
# Labels do eixo horizontal considerando o período de início de fim da coleta de dados.
lista = []
for ano in range(2020,2023,1):
    for mes in range(1,13,1):
        if mes < 10:
            lista.append(f'{ano}/0{mes}/01')
        else:
            lista.append(f'{ano}/{mes}/01')
labels_lista = lista[3:28]

# %%
labels_lista
# Out:
# ['2020/04/01',
#  '2020/05/01',
#  '2020/06/01',
#  '2020/07/01',
#  '2020/08/01',
#  '2020/09/01',
#  '2020/10/01',
#  '2020/11/01',
#  '2020/12/01',
#  '2021/01/01',
#  '2021/02/01',
#  '2021/03/01',
#  '2021/04/01',
#  '2021/05/01',
#  '2021/06/01',
#  '2021/07/01',
#  '2021/08/01',
#  '2021/09/01',
#  '2021/10/01',
#  '2021/11/01',
#  '2021/12/01',
#  '2022/01/01',
#  '2022/02/01',
#  '2022/03/01',
#  '2022/04/01']

# %%
dados0
# Out:
#           Datas  Rio de Janeiro  Dados salvos
# 0    2020/01/04             2.0           NaN
# 1    2020/01/06             1.0           NaN
# 2    2020/01/09             2.0           NaN
# 3    2020/01/11             2.0           NaN
# 4    2020/01/12             2.0           NaN
# ..          ...             ...           ...
# 808  2022/05/01            27.0           NaN
# 809  2022/05/02           272.0           NaN
# 810  2022/05/03           262.0           NaN
# 811  2022/05/04           202.0           NaN
# 812  2022/05/05             1.0           NaN
#
# [813 rows x 3 columns]

# %%
dados0['Datas']
# Out:
# 0      2020/01/04
# 1      2020/01/06
# 2      2020/01/09
# 3      2020/01/11
# 4      2020/01/12
#           ...
# 808    2022/05/01
# 809    2022/05/02
# 810    2022/05/03
# 811    2022/05/04
# 812    2022/05/05
# Name: Datas, Length: 813, dtype: object

# %%
a = dados0.index.to_numpy()

a[3]
# Out:
# 3

# %%
dados0 = pd.read_csv('/home/isplay/Área de Trabalho/Millikan.csv', skiprows=[0,1,2,3])
dados0
# Out:
#     T1 (s) T2 (s) ΔT1 (s) ΔT2 (s)  v1 (m/s)  v2 (m/s)  Q (Coul)     R (m)  \
# 0     1,37   3,04    1,37    1,67  6,50E-04  5,33E-04  1,16E-18  6,88E-07
# 1     2,02   4,81    2,02    2,79  4,41E-04  3,19E-04  7,62E-19  7,02E-07
# 2     2,18   4,94    2,18    2,76  4,08E-04  3,22E-04  6,16E-19  5,90E-07
# 3     1,39   5,56    1,39    4,17  6,40E-04  2,13E-04  1,61E-18  1,32E-06
# 4     1,71   5,75    1,71    4,04  5,20E-04  2,20E-04  1,17E-18  1,10E-06
# ..     ...    ...     ...     ...       ...       ...       ...       ...
# 115   1,65   5,25    1,65    3,60  5,39E-04  2,47E-04  1,22E-18  1,09E-06
# 116   1,59   5,47    1,59    3,88  5,60E-04  2,29E-04  1,31E-18  1,16E-06
# 117   2,56   9,07    2,56    6,51  3,48E-04  1,37E-04  6,40E-19  9,25E-07
# 118   2,62   9,28    2,62    6,66  3,40E-04  1,34E-04  6,18E-19  9,14E-07
# 119   2,68   9,28    2,68    6,60  3,32E-04  1,35E-04  5,97E-19  8,95E-07
#
#                     N  N.1 e = q/N (Coul)
# ...

# %%
cargas = dados0['e = q/N (Coul)']
cargas
# Out:
# 0      1,661E-19
# 1      1,524E-19
# 2      1,540E-19
# 3      1,605E-19
# 4      1,668E-19
#          ...
# 115    1,529E-19
# 116    1,632E-19
# 117    1,600E-19
# 118    1,546E-19
# 119    1,492E-19
# Name: e = q/N (Coul), Length: 120, dtype: object

# %%
intervalo = [ round(1.6*10**(-19) - 0.1*1.6*10**(-19),22), round(1.6*10**(-19) + 0.1*1.6*10**(-19),22) ]
intervalo
# Out:
# [1.44e-19, 1.76e-19]

# %%
cargas[0]
# Out:
# '1,661E-19'

# %%
import numpy as np, matplotlib.pyplot as plt
wavelenght = np.linspace(3000,8000,1000)
scattering = 1*10**17/(wavelenght)**4
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(wavelenght, scattering)
ax.set_ylabel('Intensidade relativa')
ax.set_xlabel('Comprimento de onda')
ax.grid(True)
ax.set_title('Espalhamento')
# Out:
# Text(0.5, 1.0, 'Espalhamento')

# %%
import numpy as np
a = np.array([6, 12, 18,0, 24, 30])
b = np.array([4, 8, 12,0, 16, 20])

log_a = np.log(a)
log_b = np.log(b)

coefficients = np.polyfit(a, log_b, 1)
print(coefficients)
# Out:
# [nan nan]
# /tmp/ipykernel_6230/1643429469.py:5: RuntimeWarning: divide by zero encountered in log
#   log_a = np.log(a)
# /tmp/ipykernel_6230/1643429469.py:6: RuntimeWarning: divide by zero encountered in log
#   log_b = np.log(b)

# %%
a = np.array([6, 12,0, 18, 24, 30,0])
b = np.array([4, 8,0, 12, 16, 20,0])

log_a = np.log(a)
log_b = np.log(b)

idx = np.isfinite(a) & np.isfinite(log_b)
coef1 = np.polynomial.polynomial.Polynomial.fit(a[idx], log_b[idx], 1)
c_linear, c_angular = coef1.convert().coef

print(c_angular, c_linear)
# Out:
# 0.06520038342380241 1.170185808047856
# /tmp/ipykernel_6230/1678124478.py:4: RuntimeWarning: divide by zero encountered in log
#   log_a = np.log(a)
# /tmp/ipykernel_6230/1678124478.py:5: RuntimeWarning: divide by zero encountered in log
#   log_b = np.log(b)

# %%
arabia0 = pd.read_csv('/home/isplay/Downloads/saudi-arabia-coronavirus-disease-covid-19-situation.csv', index_col=0)
arabia1 = arabia.loc['Daily']
arabia2 = arabia1.set_index('Indicator')
arabia3 = arabia2.loc['Cases']
arabia4 = arabia3.set_index('City')
arabia5 = arabia4.loc['Ar Riyad']
arabia6 = arabia5.set_index('Date')
arabia7 = arabia6.drop(columns=['Event','Region','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14'])

a = arabia7.index.to_numpy()
for i in range(np.size(a)):
    b = '/'.join(a[i].split('-'))
    a[i] = b

arabia7
# Out:
#            Cases (person)
# Date
# 2020/03/17             19
# 2020/03/19             21
# 2020/03/20             49
# 2020/03/25             83
# 2020/03/26             34
# ...                   ...
# 2022/05/08            102
# 2022/05/10            127
# 2022/05/14             92
# 2022/05/15            130
# 2022/05/26            112
#
# [806 rows x 1 columns]

# %%
arabia8 = arabia7.sort_index(inplace=False)
arabia8.to_csv('Riad.csv')

# %%
riad = pd.read_csv('/home/isplay/projeto_propagacao_epidemias/Códigos/Riad.csv')
riad
# Out:
#            Date  Riad
# 0    2020/03/09     1
# 1    2020/03/13     3
# 2    2020/03/14    12
# 3    2020/03/15     2
# 4    2020/03/16     4
# ..          ...   ...
# 801  2022/05/23   124
# 802  2022/05/24   122
# 803  2022/05/25   122
# 804  2022/05/26   112
# 805  2022/05/27   116
#
# [806 rows x 2 columns]

# %%
# Out:
# <AxesSubplot:>

# %%
import numpy	
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D ##library for 3d projection plots

###variable declarations
nx = 31
ny = 31
nt = 17
nu = .05
dx = 2 / (nx - 1)
dy = 2 / (ny - 1)
sigma = .25
dt = sigma * dx * dy / nu

x = numpy.linspace(0, 2, nx)
y = numpy.linspace(0, 2, ny)

u = numpy.ones((ny, nx))  # create a 1xn vector of 1's
un = numpy.ones((ny, nx))

###Assign initial conditions
# set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2  

fig = pyplot.figure(figsize=(11, 7), dpi=100)
ax = fig.gca(projection='3d')
X, Y = numpy.meshgrid(x, y)
surf = ax.plot_surface(X, Y, u, rstride=1, cstride=1, cmap=cm.viridis,
        linewidth=0, antialiased=False)

ax.set_xlim(0, 2)
ax.set_ylim(0, 2)
ax.set_zlim(1, 2.5)

ax.set_xlabel('$x$')
ax.set_ylabel('$y$');



###Run through nt timesteps
def diffuse(nt):
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2  
    
    for n in range(nt + 1): 
        un = u.copy()
        u[1:-1, 1:-1] = (un[1:-1,1:-1] + 
                        nu * dt / dx**2 * 
                        (un[1:-1, 2:] - 2 * un[1:-1, 1:-1] + un[1:-1, 0:-2]) +
                        nu * dt / dy**2 * 
                        (un[2:,1: -1] - 2 * un[1:-1, 1:-1] + un[0:-2, 1:-1]))
        u[0, :] = 1
        u[-1, :] = 1
        u[:, 0] = 1
        u[:, -1] = 1
   
    fig = pyplot.figure(figsize=(11, 7), dpi=100)
    ax = fig.gca(projection='3d')
    surf = ax.plot_surface(X, Y, u[:], rstride=1, cstride=1, cmap=cm.viridis,
        linewidth=0, antialiased=True)
    ax.set_zlim(1, 2.5)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$');
# Out:
# /tmp/ipykernel_4012/2195053916.py:26: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
import numpy              			   
from matplotlib import pyplot as plt 

# Initial Conditions
nx = 41
dx = 2 / (nx - 1)
nt = 20    #the number of timesteps we want to calculate
nu = 0.3   #the value of viscosity
sigma = .2 #sigma is a parameter, we'll learn more about it later
dt = sigma * dx**2 /nu #dt is defined using sigma ... more later!
print(dt)

u = numpy.ones(nx)      #a numpy array with nx elements all equal to 1.
u[int(.5 / dx):int(1 / dx + 1)] = 2  #setting u = 2 between 0.5 and 1 as per our I.C.s

# Calculation
un = numpy.ones(nx) #our placeholder array, un, to advance the solution in time
for n in range(nt):  #iterate through time
    un = u.copy() ##copy the existing values of u into un
    for i in range(1, nx - 1):
        u[i] = un[i] + nu * dt / dx**2 * (un[i+1] - 2 * un[i] + un[i-1])
        
    plt.plot(numpy.linspace(0, 2, nx), u);
plt.show();
# Out:
# 0.0016666666666666672

# %%
niteroi = pd.read_csv('/home/isplay/Área de Trabalho/Dados-niteroi')
niteroi
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 niteroi = pd.read_csv('/home/isplay/Área de Trabalho/Dados-niteroi')
#       2 niteroi
#
# File /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
