# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd
from scipy.integrate import solve_ivp

# %%
def grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível):
    
    meio = int((oeste+leste)/2)
    um_quarto = int((oeste+meio)/2)
    tres_quartos = int((meio+leste)/2)

    dados0_y_rio = dados0[nome_cidade][oeste:leste].to_numpy()/população_suscetível
    dados0_x_rio = dados0.index[oeste:leste].to_numpy()
    
    if dados_limpos == True:
        dados1_y_rio = dados1[nome_cidade][oeste:leste].to_numpy()/população_suscetível
        dados1_x_rio = dados1.index[oeste:leste].to_numpy()

    fig, ax = plt.subplots(figsize=(15,8))

    ax.scatter(dados0_x_rio, dados0_y_rio, alpha=1, label='Dados limpos')

    ax.plot(res.t, res.y[1], 'r', label='Infectados SIR')
    
    if dados_limpos == True:
        ax.plot(dados1_x_rio, dados1_y_rio,'*-r', alpha=0.3, label='Dados coletados')

    ax.grid(True)
    ax.set_ylabel('Densidade populacional')
    ax.set_xlabel('Dias consecutivos')
    ax.legend(frameon=False, loc='upper left')
    label = [dados0.loc[oeste]['Datas'],dados0.loc[um_quarto]['Datas'],dados0.loc[meio]['Datas'],
              dados0.loc[tres_quartos]['Datas'],dados0.loc[leste]['Datas']]
    ax.set_xticks([oeste,um_quarto,meio,tres_quartos,leste], labels=label)

    ax.set_xlim([x_esq,x_dir])
    
    ax.set_title(f'Casos + simulação; População total: {população_total}; População suscetível: {população_suscetível}')
    
    return

# %%
# Niterói - 0

# Entrada
url0 = 'https://raw.githubusercontent.com/isplay/projeto_propagacao_epidemias/main/csv_dados_limpos/Niter%C3%B3i_casos_limpos.csv'
dados0 = pd.read_csv(url0)
dados_limpos = True
url1 = 'https://raw.githubusercontent.com/isplay/projeto_propagacao_epidemias/main/csv/Niter%C3%B3i_casos.csv'
dados1 = pd.read_csv(url1)

# Região
população_total = 516981
população_suscetível = 516981 - 506000
nome_cidade = 'Niterói'

# Intervalo de dias total
oeste = 586
leste = 760

# Intervalo no eixo horizontal no gráfico
x_esq = 640
x_dir = 720


#SIR
def sir(t, y):
    
    s, i, r = y
    
    dsdt = - R0*s*i
    didt = R0*s*i - i + l*r*i
    drdt = i - l*r*i
    
    return dsdt, didt, drdt

# Condições iniciais

coef_s = 0.259017367293413 # FIT

l = 0.865

R0 = coef_s + 1
t0, t = oeste, leste
i0 = 1e-10
r0 = 0
s0 = 1 - i0 - r0

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
# Niterói - 1

# Entrada
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Niteroi_COVIDBR.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Niteroi_COVIDBR (cópia).csv')

# Região
população_total = 516981
população_suscetível = 516981 - 506000
nome_cidade = 'Niterói'

# Intervalo de dias total
oeste = 592
leste = 780

# Intervalo no eixo horizontal no gráfico
x_esq = 640
x_dir = 740


#SIR
def sir(t, y):
    
    s, i, r = y
    
    dsdt = - R0*s*i + g*r
    didt = R0*s*i - i + l*r*i
    drdt = i - l*r*i - g*r
    
    return dsdt, didt, drdt

# Condições iniciais

R0 = 1.1306 #FIT

l = 0.9
g = 0.0


t0, t = oeste, leste
i0 = 1/população_total
r0 = 0
s0 = 1 - i0 - r0

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
# Niterói - 2

# Entrada
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Niteroi_COVIDBR.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Niteroi_COVIDBR (cópia).csv')

# Região
população_total = 516981
população_suscetível = população_total - 475000
nome_cidade = 'Niterói'

# Intervalo de dias total
oeste = 609
leste = 780

# Intervalo no eixo horizontal no gráfico
x_esq = 640
x_dir = 750


#SIR
def sir(t, y):
    
    s, i, r = y
    
    dsdt = - R0*s*i + g*r
    didt = R0*s*i - i
    drdt = i - g*r
    
    return dsdt, didt, drdt

# Condições iniciais

R0 = 1.14
g = 0.025

t0, t = oeste, leste
i0 = 1/população_total
r0 = 0
s0 = 1 - i0 - r0

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
# Rio de Janeiro - 0

# Entrada
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Rio_COVIDBR.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Rio_COVIDBR (cópia).csv')

# Região
população_total = 6320446
população_suscetível = população_total - 5500000
nome_cidade = 'Rio de Janeiro'

# Intervalo de dias total
oeste = 592
leste = 780

# Intervalo no eixo horizontal no gráfico
x_esq = 620
x_dir = 740


#SIR
def sir(t, y):
    s, i, r = y
    
    dsdt = - R0*s*i
    didt = R0*s*i - i + l*r*i
    drdt = i - l*i*r
    
    return dsdt, didt, drdt

# Condições iniciais

R0 = 1.15
l = 0.65

t0, t = oeste, leste
i0 = 1/população_suscetível
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
# Rio de Janeiro - 1

# Entrada
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Rio_COVIDBR.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Rio_COVIDBR (cópia).csv')

# Região
população_total = 6320446
população_suscetível = população_total - 4500000
nome_cidade = 'Rio de Janeiro'

# Intervalo de dias total
oeste = 588
leste = 780

# Intervalo no eixo horizontal no gráfico
x_esq = 620
x_dir = 740


#SIR
def sir(t, y):
    s, i, r = y
    
    dsdt = - R0*s*i + g*r
    didt = R0*s*i - i + l*r*i
    drdt = i - g*r - l*r*i
    
    return dsdt, didt, drdt

# Condições iniciais

R0 = 1.14 #FIT + 0.01
g = 0.02
l = 0.0

t0, t = oeste, leste
i0 = 1/população_suscetível
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
# Buenos Aires - 0

# Entrada
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv_dados_limpos/Buenos_Aires_casos_limpos.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv/Buenos_Aires_casos.csv')

# Região
população_total = 2891082
população_suscetível = população_total - 2100000
nome_cidade = 'Buenos Aires'

# Intervalo de dias total
oeste = 628
leste = 780

# Intervalo no eixo horizontal no gráfico
x_esq = 650
x_dir = 750


#SIR
def sir(t, y):
    s, i, r = y
    
    dsdt = - R0*s*i + g*r
    didt = R0*s*i - i
    drdt = i - g*r
    
    return dsdt, didt, drdt

# Condições iniciais

R0 = 1.1627 #FIT
g = 0.016

t0, t = oeste, leste
i0 = 1/população_suscetível
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
# Região Metropolitana de Santiago - Chile

# Dados
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv_dados_limpos/Região_Metropolitana_de_Santiago_casos_limpos.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv/Região_Metropolitana_de_Santiago_casos.csv')

# Região
população_total = 7003122
população_suscetível = população_total - 5000000
nome_cidade = 'Região Metropolitana de Santiago'

# Intervalo de dias total
oeste = 599
leste = 760

# Intervalo no eixo horizontal no gráfico
x_esq = 650
x_dir = 760


#SIR
def sir(t, y):
    s, i, r = y
    
    dsdt = - R0*s*i + g*r
    didt = R0*s*i - i
    drdt = i - g*r
    
    return dsdt, didt, drdt

# Condições iniciais

R0 = 1.115 #FIT
g = 0.018

t0, t = oeste, leste
i0 = 1/população_suscetível
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
# Tokyo distrito - Japão

# Dados
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv_dados_limpos/Tóquio_casos_limpos.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv/Tóquio_casos.csv')

# Região

# Região
população_total = 13503810
população_suscetível = população_total - 13200000
nome_cidade = 'Tóquio'

# Intervalo de dias total
oeste = 623
leste = 770

# Intervalo no eixo horizontal no gráfico
x_esq = 650
x_dir = 770


#SIR
def sir(t, y):
    s, i, r = y
    
    dsdt = - R0*s*i + g*r
    didt = R0*s*i - i + l*r*i
    drdt = i - l*r*i - g*r
    
    return dsdt, didt, drdt

# Condições iniciais

R0 = 1.18 #FIT
l = 0.99
g = 0.007


t0, t = oeste, leste
i0 = 1/população_suscetível
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
# Paris - France

# Dados
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv_dados_limpos/Paris_casos_limpos.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv/Paris_casos.csv')

# Região
população_total = 2148271
população_suscetível = população_total
nome_cidade = 'Paris'

# Intervalo de dias total
oeste = 510
leste = 700

# Intervalo no eixo horizontal no gráfico
x_esq = 530
x_dir = 700



#SIR
def sir(t, y):
    s, i, r = y
    
    dsdt = - R0*s*i + g*r
    didt = R0*s*i - i + l*r*i
    drdt = i - l*r*i - g*r
    
    return dsdt, didt, drdt

# Condições iniciais

R0 = 1.12 #FIT
l = 0.
g = 0.018


t0, t = oeste, leste
i0 = 1/população_total
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
# Riad - Arábia Saudita

# Dados
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv/Riad_casos.csv')
dados_limpos = False
dados1 = 0

# Região
população_total = 7676654
população_suscetível = população_total - 7500000
nome_cidade = 'Riad'

# Intervalo de dias total
oeste = 599
leste = 740

# Intervalo no eixo horizontal no gráfico
x_esq = 630
x_dir = 740



#SIR
def sir(t, y):
    s, i, r = y
    
    dsdt = - R0*s*i + g*r
    didt = R0*s*i - i + l*r*i
    drdt = i - l*r*i - g*r
    
    return dsdt, didt, drdt

# Condições iniciais

R0 = 1.16 #FIT
l = 0.0
g = 0.02


t0, t = oeste, leste
i0 = 1/população_total
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
# Tanguá - Estado do Rio de Janeiro

# Dados
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv_dados_limpos/Tanguá_casos_limpos.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv/Tanguá_casos.csv')

# Região
população_total = 34898
população_suscetível = população_total - 28000
nome_cidade = 'Tanguá'

# Intervalo de dias total
oeste = 548
leste = 630

# Intervalo no eixo horizontal no gráfico
x_esq = 550
x_dir = 630



#SIR
def sir(t, y):
    s, i, r = y
    
    dsdt = - R0*s*i + g*r
    didt = R0*s*i - i + l*r*i
    drdt = i - l*r*i - g*r
    
    return dsdt, didt, drdt

# Condições iniciais

R0 = 1.26 #FIT
l = 0.
g = 0.


t0, t = oeste, leste
i0 = 1/população_total
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 

# Simulando o Modelo SIR
resolucao_curva = np.linspace(t0,t,leste-oeste)
res = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=resolucao_curva, method='LSODA')

# Plot
grafico(oeste, leste, dados0, dados_limpos, dados1, população_total, população_suscetível)

# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd

pacote_coef_s = []
pacote_coef_d = []

def grafico(dados0, dados_limpos, dados1, oeste, leste, população, nome_cidade, escala_log_linear):
    
    meio = int((oeste+leste)/2)
    um_quarto = int((oeste+meio)/2)
    tres_quartos = int((meio+leste)/2)

    dados0_y_rio = dados0[nome_cidade][oeste:leste].to_numpy()/população
    dados_x = dados0.index[oeste:leste].to_numpy()

    if dados_limpos == True:
        dados1_y = dados1[nome_cidade][oeste:leste].to_numpy()/população
        dados1_x = dados1.index[oeste:leste].to_numpy()

    fig, ax = plt.subplots(figsize=(15,8))
    ax.scatter(dados_x, dados0_y_rio, alpha=1, label='Dados limpos')
    
    if dados_limpos == True:
        ax.plot(dados1_x, dados1_y,'*-r', alpha=0.3, label='Dados coletados')
        
    ax.grid(True)
    ax.set_ylabel('Densidade populacional')
    ax.set_xlabel('Dias')
    ax.legend(frameon=False)
    #fig.autofmt_xdate(rotation=45)
    label = [dados0.loc[oeste]['Datas'],dados0.loc[um_quarto]['Datas'],dados0.loc[meio]['Datas'],
              dados0.loc[tres_quartos]['Datas'],dados0.loc[leste]['Datas']]
    ax.set_xticks([oeste,um_quarto,meio,tres_quartos,leste], labels=label)

    if escala_log_linear == True:
        plt.yscale('log')
    
    plt.title(f'Casos confirmados: {nome_cidade}; {população} habitantes.')
    return

def fit(dados0, oeste, leste, população, nome_cidade, pre_pico):
    
    meio = int((oeste+leste)/2)
    um_quarto = int((oeste+meio)/2)
    tres_quartos = int((meio+leste)/2)

    dados0_y_log = np.log(dados0[nome_cidade][oeste:leste].to_numpy()/população)
    dados_x = dados0.index[oeste:leste].to_numpy()

    idx = np.isfinite(dados_x) & np.isfinite(dados0_y_log)
    coef1 = np.polynomial.polynomial.Polynomial.fit(dados_x[idx], dados0_y_log[idx], 1)
    coef_l, coef_a = coef1.convert().coef

    fig, ax = plt.subplots(figsize=(15,8))

    ax.scatter(dados_x, dados0_y_log, label='Dados reais')
    ax.plot(dados_x, coef_l + coef_a*dados_x, 'r',label='Curva de ajuste')

    ax.text(0.3, 0.9, f'Reta: y = {round(coef_l,9)} + {round(coef_a,9)}*x', fontsize=13,style='italic', transform=ax.transAxes)

    ax.grid(True)
    ax.set_ylabel('Logaritmo natural da densidade populacional')
    ax.set_xlabel('Dias')
    ax.legend(frameon=False)

    label = [dados0.loc[oeste]['Datas'],dados0.loc[um_quarto]['Datas'],dados0.loc[meio]['Datas'],
              dados0.loc[tres_quartos]['Datas'],dados0.loc[leste]['Datas']]
    ax.set_xticks([oeste,um_quarto,meio,tres_quartos,leste], labels=label)
    
    if pre_pico == True:
        frase = 'Ajuste linear antes do pico'
        pacote_coef_s.append([nome_cidade,coef_a])

    else:
        frase = 'Ajuste linear após o pico'
        pacote_coef_d.append([coef_a])

    plt.title(f'{frase}; {nome_cidade}; {população} habitantes.')
        
    return coef_a

# %%
# FIT

# Entrada
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Niteroi_COVIDBR.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Niteroi_COVIDBR (cópia).csv')

# Região
população = 515317
nome_cidade = 'Niterói'

# Intervalos
oeste = 630
leste = 680

# Log-linear
escala_log_linear = True

# Plot
grafico(dados0, dados_limpos, dados1, oeste, leste, população, nome_cidade, escala_log_linear)

# Subida
oeste = 643
leste = 673
pre_pico = True
coef_s = fit(dados0, oeste, leste, população, nome_cidade, pre_pico)

# Descida
oeste = 690
leste = 740
pre_pico = False
coef_d = fit(dados0, oeste, leste, população, nome_cidade, pre_pico)
# Out:
# /tmp/ipykernel_9735/110514901.py:46: RuntimeWarning: divide by zero encountered in log
#   dados0_y_log = np.log(dados0[nome_cidade][oeste:leste].to_numpy()/população)

# %%
# FIT - Rio de Janeiro

# Entrada
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Rio_COVIDBR.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Rio_COVIDBR (cópia).csv')

# Região
população = 6320446
nome_cidade = 'Rio de Janeiro'

# Intervalos
oeste = 630
leste = 720

# Log-linear
escala_log_linear = False

# Plot
grafico(dados0, dados_limpos, dados1, oeste, leste, população, nome_cidade, escala_log_linear)

# Subida
oeste = 650
leste = 662
pre_pico = True
coef_s = fit(dados0, oeste, leste, população, nome_cidade, pre_pico)

# Descida
oeste = 690
leste = 740
pre_pico = False
coef_d = fit(dados0, oeste, leste, população, nome_cidade, pre_pico)
# Out:
# /tmp/ipykernel_9735/110514901.py:46: RuntimeWarning: divide by zero encountered in log
#   dados0_y_log = np.log(dados0[nome_cidade][oeste:leste].to_numpy()/população)

# %%
# Buenos Aires - Argentina

# Dados
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv_dados_limpos/Buenos_Aires_casos_limpos.csv')
dados_limpos = True
dados1 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/csv/Buenos_Aires_casos.csv')

# Região
população = 2891082
nome_cidade = 'Buenos Aires'

# Intervalos
oeste = 660
leste = 750

# Log-linear
escala_log_linear = False

# Plot
grafico(dados0, dados_limpos, dados1, oeste, leste, população, nome_cidade, escala_log_linear)

# Subida
oeste = 660
leste = 682
pre_pico = True
coef_s = fit(dados0, oeste, leste, população, nome_cidade, pre_pico)
 
# Descida
oeste = 700
leste = 736
pre_pico = False
coef_d = fit(dados0, oeste, leste, população, nome_cidade, pre_pico)
