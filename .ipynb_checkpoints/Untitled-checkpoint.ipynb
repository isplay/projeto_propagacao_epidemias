# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd
from scipy.integrate import solve_ivp

# %%
niteroi_2_0 = pd.read_csv('/home/isplay/Área de Trabalho/Dados_niteroi/HIST_PAINEL_COVIDBR_2020_Parte1_22jun2022.csv', index_col=2)
niteroi_2_1 = niteroi_2_0.loc['Rio de Janeiro']
niteroi_2_2_0 = niteroi_2_1.drop(columns=['regiao', 'estado', 'coduf', 'codmun', 'codRegiaoSaude','nomeRegiaoSaude', 'semanaEpi', 'populacaoTCU2019',
       'casosAcumulado', 'obitosAcumulado',
       'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana',
       'Unnamed: 17'])
niteroi_2_2_0
# Out:
# /tmp/ipykernel_7730/1749117184.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   niteroi_2_0 = pd.read_csv('/home/isplay/Área de Trabalho/Dados_niteroi/HIST_PAINEL_COVIDBR_2020_Parte1_22jun2022.csv', index_col=2)
#                       data  casosNovos  obitosNovos
# municipio
# Rio de Janeiro  2020-03-27         0.0          0.0
# Rio de Janeiro  2020-03-28       489.0          9.0
# Rio de Janeiro  2020-03-29        27.0          4.0
# Rio de Janeiro  2020-03-30        37.0          0.0
# Rio de Janeiro  2020-03-31        33.0          5.0
# ...                    ...         ...          ...
# Rio de Janeiro  2020-07-27       800.0         30.0
# Rio de Janeiro  2020-07-28        70.0         71.0
# Rio de Janeiro  2020-07-29       252.0         96.0
# Rio de Janeiro  2020-07-30       297.0         50.0
# Rio de Janeiro  2020-07-31       333.0         40.0
#
# [127 rows x 3 columns]

# %%
niteroi_2_0 = pd.read_csv('/home/isplay/Área de Trabalho/Dados_niteroi/HIST_PAINEL_COVIDBR_2020_Parte2_22jun2022.csv', index_col=2)
niteroi_2_1 = niteroi_2_0.loc['Rio de Janeiro']
niteroi_2_2_1 = niteroi_2_1.drop(columns=['regiao', 'estado', 'coduf', 'codmun', 'codRegiaoSaude','nomeRegiaoSaude', 'semanaEpi', 'populacaoTCU2019',
       'casosAcumulado', 'obitosAcumulado',
       'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana',
       'Unnamed: 17'])
niteroi_2_2_1
# Out:
# /tmp/ipykernel_7730/3429369971.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   niteroi_2_0 = pd.read_csv('/home/isplay/Área de Trabalho/Dados_niteroi/HIST_PAINEL_COVIDBR_2020_Parte2_22jun2022.csv', index_col=2)
#                       data  casosNovos  obitosNovos
# municipio
# Rio de Janeiro  2020-08-01       470.0         34.0
# Rio de Janeiro  2020-08-02        10.0         14.0
# Rio de Janeiro  2020-08-03       277.0         13.0
# Rio de Janeiro  2020-08-04       643.0         48.0
# Rio de Janeiro  2020-08-05       674.0         80.0
# ...                    ...         ...          ...
# Rio de Janeiro  2020-12-27       461.0          6.0
# Rio de Janeiro  2020-12-28       188.0         16.0
# Rio de Janeiro  2020-12-29      1581.0         85.0
# Rio de Janeiro  2020-12-30      2010.0        110.0
# Rio de Janeiro  2020-12-31       297.0        117.0
#
# [153 rows x 3 columns]

# %%
niteroi_2_0 = pd.read_csv('/home/isplay/Área de Trabalho/Dados_niteroi/HIST_PAINEL_COVIDBR_2021_Parte1_22jun2022.csv', index_col=2)
niteroi_2_1 = niteroi_2_0.loc['Rio de Janeiro']
niteroi_2_2_2 = niteroi_2_1.drop(columns=['regiao', 'estado', 'coduf', 'codmun', 'codRegiaoSaude','nomeRegiaoSaude', 'semanaEpi', 'populacaoTCU2019',
       'casosAcumulado', 'obitosAcumulado',
       'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana',
       'Unnamed: 17'])
niteroi_2_2_2
# Out:
# /tmp/ipykernel_7730/3745465456.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   niteroi_2_0 = pd.read_csv('/home/isplay/Área de Trabalho/Dados_niteroi/HIST_PAINEL_COVIDBR_2021_Parte1_22jun2022.csv', index_col=2)
#                       data  casosNovos  obitosNovos
# municipio
# Rio de Janeiro  2021-01-01        79.0         45.0
# Rio de Janeiro  2021-01-02         5.0          1.0
# Rio de Janeiro  2021-01-03        26.0          7.0
# Rio de Janeiro  2021-01-04      2669.0          2.0
# Rio de Janeiro  2021-01-05      1514.0        162.0
# ...                    ...         ...          ...
# Rio de Janeiro  2021-06-26      1538.0         68.0
# Rio de Janeiro  2021-06-27       386.0          3.0
# Rio de Janeiro  2021-06-28        35.0         10.0
# Rio de Janeiro  2021-06-29      1420.0         88.0
# Rio de Janeiro  2021-06-30       232.0        110.0
#
# [181 rows x 3 columns]

# %%
niteroi_2_0 = pd.read_csv('/home/isplay/Área de Trabalho/Dados_niteroi/HIST_PAINEL_COVIDBR_2021_Parte2_22jun2022.csv', index_col=2)
niteroi_2_1 = niteroi_2_0.loc['Rio de Janeiro']
niteroi_2_2_3 = niteroi_2_1.drop(columns=['regiao', 'estado', 'coduf', 'codmun', 'codRegiaoSaude','nomeRegiaoSaude', 'semanaEpi', 'populacaoTCU2019',
       'casosAcumulado', 'obitosAcumulado',
       'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana',
       'Unnamed: 17'])
niteroi_2_2_3
# Out:
# /tmp/ipykernel_7730/1425862391.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   niteroi_2_0 = pd.read_csv('/home/isplay/Área de Trabalho/Dados_niteroi/HIST_PAINEL_COVIDBR_2021_Parte2_22jun2022.csv', index_col=2)
#                       data  casosNovos  obitosNovos
# municipio
# Rio de Janeiro  2021-07-01       775.0        115.0
# Rio de Janeiro  2021-07-02       884.0         74.0
# Rio de Janeiro  2021-07-03       748.0         58.0
# Rio de Janeiro  2021-07-04       196.0          1.0
# Rio de Janeiro  2021-07-05       164.0          2.0
# ...                    ...         ...          ...
# Rio de Janeiro  2021-12-27        32.0         13.0
# Rio de Janeiro  2021-12-28        -2.0          2.0
# Rio de Janeiro  2021-12-29         5.0          2.0
# Rio de Janeiro  2021-12-30         6.0          2.0
# Rio de Janeiro  2021-12-31         0.0          0.0
#
# [184 rows x 3 columns]

# %%
niteroi_2_0 = pd.read_csv('/home/isplay/Área de Trabalho/Dados_niteroi/HIST_PAINEL_COVIDBR_2022_Parte1_22jun2022.csv', index_col=2)
niteroi_2_1 = niteroi_2_0.loc['Rio de Janeiro']
niteroi_2_2_4 = niteroi_2_1.drop(columns=['regiao', 'estado', 'coduf', 'codmun', 'codRegiaoSaude','nomeRegiaoSaude', 'semanaEpi', 'populacaoTCU2019',
       'casosAcumulado', 'obitosAcumulado',
       'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana',
       'Unnamed: 17'])
niteroi_2_2_4
# Out:
# /tmp/ipykernel_7730/855663894.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   niteroi_2_0 = pd.read_csv('/home/isplay/Área de Trabalho/Dados_niteroi/HIST_PAINEL_COVIDBR_2022_Parte1_22jun2022.csv', index_col=2)
#                       data  casosNovos  obitosNovos
# municipio
# Rio de Janeiro  2022-01-01         0.0          0.0
# Rio de Janeiro  2022-01-02         0.0          0.0
# Rio de Janeiro  2022-01-03      3895.0          0.0
# Rio de Janeiro  2022-01-04      2045.0          8.0
# Rio de Janeiro  2022-01-05      3079.0         -2.0
# ...                    ...         ...          ...
# Rio de Janeiro  2022-06-18         0.0          0.0
# Rio de Janeiro  2022-06-19         0.0          0.0
# Rio de Janeiro  2022-06-20      5980.0          1.0
# Rio de Janeiro  2022-06-21      5732.0          3.0
# Rio de Janeiro  2022-06-22      4837.0          0.0
#
# [173 rows x 3 columns]

# %%
resultado = pd.concat([niteroi_2_2_0,niteroi_2_2_1,niteroi_2_2_2,niteroi_2_2_3,niteroi_2_2_4])
resultado.to_csv('Rio_COVIDBR.csv')

# %%
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Rio_COVIDBR.csv', index_col=0)
dados0
# Out:
#             Rio de Janeiro  óbitos
# Datas
# 2020/03/27             0.0     0.0
# 2020/03/28           489.0     9.0
# 2020/03/29            27.0     4.0
# 2020/03/30            37.0     0.0
# 2020/03/31            33.0     5.0
# ...                    ...     ...
# 2022/06/18             0.0     0.0
# 2022/06/19             0.0     0.0
# 2022/06/20          5980.0     1.0
# 2022/06/21          5732.0     3.0
# 2022/06/22          4837.0     0.0
#
# [818 rows x 2 columns]

# %%
a = dados0.index.to_numpy()
for i in range(np.size(a)):
    b = '/'.join(a[i].split('-'))
    a[i] = b

dados0.to_csv('Rio_COVIDBR.csv')

# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd

def grafico(dados0, dados_limpos, dados1, oeste, leste, população, nome_cidade, escala_log_linear):
    
    meio = int((oeste+leste)/2)
    um_quarto = int((oeste+meio)/2)
    tres_quartos = int((meio+leste)/2)

    dados0_y_rio = dados0[nome_cidade][oeste:leste].to_numpy()/população
    dados_x = dados0.index[oeste:leste].to_numpy()

    if dados_limpos == True:
        dados1_y = dados1[nome_cidade][oeste:leste].to_numpy()/população
        dados1_x = dados1.index[oeste:leste].to_numpy()

    fig, ax = plt.subplots(figsize=(15,8))
    ax.scatter(dados_x, dados0_y_rio, alpha=1, label='Dados limpos')
    
    if dados_limpos == True:
        ax.plot(dados1_x, dados1_y,'*-r', alpha=0.3, label='Dados coletados')
        
    ax.grid(True)
    ax.set_ylabel('Densidade populacional')
    ax.set_xlabel('Dias')
    ax.legend(frameon=False)
    #fig.autofmt_xdate(rotation=45)
    label = [dados0.loc[oeste]['Datas'],dados0.loc[um_quarto]['Datas'],dados0.loc[meio]['Datas'],
              dados0.loc[tres_quartos]['Datas'],dados0.loc[leste]['Datas']]
    ax.set_xticks([oeste,um_quarto,meio,tres_quartos,leste], labels=label)

    if escala_log_linear == True:
        plt.yscale('log')
    
    plt.title(f'Casos confirmados: {nome_cidade}; {população} habitantes.')
    
    return

# %%
# Niteroi_COVIDBR

# Entrada
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Niteroi_COVIDBR.csv')
dados_limpos = False
dados1 = 0

# Região
população = 515317
nome_cidade = 'Rio de Janeiro'

# Intervalos
oeste = 640
leste = 720

# Log-linear
escala_log_linear = False

# Plot
grafico(dados0, dados_limpos, dados1, oeste, leste, população, nome_cidade, escala_log_linear)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rio de Janeiro'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Niteroi_prefeitura

# Entrada
dados0 = pd.read_csv('/home/isplay/projeto_propagacao_epidemias-main/Niteroi_prefeitura.csv')
dados_limpos = False
dados1 = 0

# Região
população = 515317
nome_cidade = 'Rio de Janeiro'

# Intervalos
oeste = 538
leste = 599

# Log-linear
escala_log_linear = False

# Plot
grafico(dados0, dados_limpos, dados1, oeste, leste, população, nome_cidade, escala_log_linear)
