# %%
import numpy as np, matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
# SIR + ???


##########################
# SIR

def sir(t, y):
    s, i, r = y
    dsdt = - R0 * s * i
    didt = R0 * s * i - i
    drdt = i
    return dsdt, didt, drdt

R0 = 1.5

t0, t = 0, 60

i0 = 1e-5
r0 = 0
s0 = 1 - i0 - r0

t_discreto = np.linspace(t0,t,1000)

res_SIR = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=t_discreto, method='LSODA')


##########################
# ???

def sir(t, y):
    s, i, r, m = y
    
    dsdt = - R0*s*i
    didt = R0*s*i - i + l*r*i
    drdt = i - l*i*r - u*r
    dmdt = u*r
    
    return dsdt, didt, drdt, dmdt

R0 = 1.5
l = 1
u = 0.005

t0, t = 0, 60

i0 = 1e-5
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 - m0

t_discreto = np.linspace(t0,t,1000)

res_unknow = solve_ivp(sir, (t0, t), y0=[s0, i0, r0, m0], t_eval=t_discreto, method='LSODA')


#######################

fig, ax = plt.subplots(figsize=(15,10))

ax.plot(res_SIR.t, res_SIR.y[1], '--g', label='Inf.SIR')
ax.plot(res_unknow.t, res_unknow.y[1], '--r', label='Inf.SIR')


ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.set_xlabel('Dias')
ax.legend(frameon=False)

#plt.yscale('log')
#ax.set_ylim([0,0.2])

# %%
# SIR + SMIR


##########################
# SIR

def sir(t, y):
    s, i, r = y
    dsdt = - R0 * s * i
    didt = R0 * s * i - i
    drdt = i
    return dsdt, didt, drdt

R0 = 1.5

t0, t = 0, 60

i0 = 1e-5
r0 = 0
s0 = 1 - i0 - r0

t_discreto = np.linspace(t0,t,1000)

res_SIR = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=t_discreto, method='LSODA')


##########################
# SMIR

def smir(t, y):
    s, m, i, r = y
    
    dsdt = - R0*s*i - δ*s
    dmdt = δ*s - ε*m*i
    didt = R0*s*i + ε*m*i - i + l*r*i*r
    drdt = i - l*r*i*r
    
    return dsdt, dmdt, didt, drdt

R0 = 1.5

t0, t = 0, 60

l = 1

# Divididos sobre gamma
δ  = 0
ε  = 0

i0 = 1e-5
r0 = 0
m0 = 0
s0 = 1 - m0 - i0 - r0

t_discreto = np.linspace(t0,t,1000)

res_SMIR = solve_ivp(smir, (t0, t), y0=[s0, m0, i0, r0], t_eval=t_discreto, method='LSODA')

#######################

fig, ax = plt.subplots(figsize=(15,10))

ax.plot(res_SMIR.t, res_SMIR.y[2], 'r', label='Inf.SMIR')
ax.plot(res_SIR.t, res_SIR.y[1], '--g', label='Inf.SIR')

ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.set_xlabel('Dias')
ax.legend(frameon=False)

#plt.yscale('log')
ax.set_ylim([0,0.2])
# Out:
# (0.0, 0.2)

# %%
# SIR + SMIR(tanh)


##########################
# SIR

def sir(t, y):
    s, i, r = y

    R0 = - C*np.tanh(t-t_pico) + O

    dsdt = - R0 * s * i
    didt = R0 * s * i - i
    drdt = i
    return dsdt, didt, drdt

# Rio de Janeiro
#coef_s = 0.1615219031945897
#coef_d = -0.10009838636511394
#R0_s = 0.1615219031945897 + 1
#R0_d = 1/(1-(coef_d))

R0_s = 1.5
R0_d = 1.5

t_pico = 30

O = (R0_s+R0_d)/2
C = R0_s - O

t0, t = 0, 60

i0 = 1e-5
r0 = 0
s0 = 1 - i0 - r0

t_discreto = np.linspace(t0,t,1000)

res_SIR = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=t_discreto, method='LSODA')


##########################
# SMIR

def smir(t, y):
    s, m, i, r = y
    
    δ = - A*np.tanh(t-t_δ) + M
    ε = - B*np.tanh(t-t_ε) + N
    β = - D*np.tanh(t-t_pico) + P

    dsdt = - β*s*i - δ*s
    dmdt = δ*s - ε*m*i
    didt = β*s*i + ε*m*i - γ*i
    drdt = γ*i
    return dsdt, dmdt, didt, drdt

"""
coef_s = 0.1615219031945897
coef_d = -0.10009838636511394

β_s = coef_s + 1
β_d = 1/(1-(coef_d))
"""

β_s = 1.5
β_d = 1.5

t_pico = 30
P = (β_s+β_d)/2
D = β_s - O

t0, t = 0, 60

γ = 1

δ0 = 0
δ  = 0.05      # Uso de máscaras
t_δ = 25       # dia
M = (δ0+δ)/2
A = δ0 - M

ε0 = 0
ε  = 0.4       # Contato dos mascarados com os indivíduos infectados.
t_ε = 30       # dia 
N = (ε0+ε)/2
B = ε0 - N

i0 = 1e-5
r0 = 0
m0 = 0
s0 = 1 - m0 - i0 - r0

t_discreto = np.linspace(t0,t,1000)

res_SMIR = solve_ivp(smir, (t0, t), y0=[s0, m0, i0, r0], t_eval=t_discreto, method='LSODA')

#######################

fig, ax = plt.subplots(figsize=(15,10))

ax.plot(res_SMIR.t, res_SMIR.y[2], 'r', label='Inf.SMIR')
ax.plot(res_SIR.t, res_SIR.y[1], '--g', label='Inf.SIR')

ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.set_xlabel('Dias')
ax.legend(frameon=False)

ax.set_ylim([0,1e-1])

# %%
t0, t = 0, 40

##########################
# SIR

def sir(t, y):
    s, i, r = y
    
    R0 = - A*np.tanh(t-t_R0) + M
    
    dsdt = - R0 * s * i
    didt = R0 * s * i - i
    drdt = i
    return dsdt, didt, drdt

# Taxa de infectados
R0_s = 1.5
R0_d  = 1.5
t_R0 = 20
M = (R0_s+R0_d)/2
A = R0_s - M

i0 = 1e-5
r0 = 0
s0 = 1 - i0 - r0

t_discreto = np.linspace(t0,t,1000)

res_SIR = solve_ivp(sir, (t0, t), y0=[s0, i0, r0], t_eval=t_discreto, method='LSODA')


##########################
# SMIR

def smir(t, y, β, ε, δ, γ):
    s, m, i, r = y
    
    δ = - A*np.tanh(t-t_δ) + M
    ε = - B*np.tanh(t-t_ε) + N
    
    dsdt = - β*s*i - δ*s
    dmdt = δ*s - ε*m*i
    didt = β*s*i + ε*m*i - γ*i
    drdt = γ*i
    
    return dsdt, dmdt, didt, drdt

β = 1.5

γ = 1

# Decaimento para mascarados
δ0 = 0
δ  = 0.2     # Uso de máscaras
t_δ = 20     # dia
M = (δ0+δ)/2
A = δ0 - M

# Contato mascarados com infectados
ε0 = 0
ε  = 0.1     # Contato dos mascarados com os indivíduos infectados.
t_ε = 25     # dia 
N = (ε0+ε)/2
B = ε0 - N

i0 = 1e-5
r0 = 0
m0 = 0
s0 = 1 - m0 - i0 - r0

t_discreto = np.linspace(t0,t,1000)

res_SMIR = solve_ivp(smir, (t0, t), y0=[s0, m0, i0, r0], args=( β, ε, δ, γ), t_eval=t_discreto, method='LSODA')

######################
# SIRD

def sird(t,y):
    s, i, d, r = y

    γ = - C*np.tanh(t-t_γ) + O
    delta = - D*np.tanh(t-t_delta) + P
    beta = - E*np.tanh(t-t_beta) + Q 

    dsdt = -beta*s*i
    didt = beta*s*i - γ*i - delta*i
    drdt = γ*i
    dmdt = delta*i
    
    return dsdt, didt, drdt, dmdt

# Taxa de infectados
beta0 = 1.5
beta  = 1.5     
t_beta = 20
Q = (beta0+beta)/2
E = beta0 - Q

# Taxa de recuperados
γ0 = 1
γ  = 1   
t_γ = 25    
O = (γ0+γ)/2
C = γ0 - O

# Taxa de fatalidade
delta0 = 0
delta = 0.2      
t_delta = 25     
P = (delta0+delta)/2
D = delta0 - P


beta  = 1.5
delta = 0.2
γ = 1

i0 = 1e-5
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 - m0

resolucao_curva = np.linspace(t0,t,1000)

res_SIRD = solve_ivp(sird, (t0, t), y0=[s0, i0, r0, m0], t_eval=resolucao_curva )

#######################
# SWIR

def swir(t, y, β, ε, δ, γ):
    s, w, i, r = y

    dsdt = - β*s*i - δ*s*i
    dwdt = δ*s*i - ε*w*i
    didt = β*s*i + ε*w*i - γ*i
    drdt = γ*i

    return dsdt, dwdt, didt, drdt

ε  = 0.1   # Contato do fraco com o infectado
δ  = 1     # Enfraquecimento dos indivíduos
β = 1.5
γ = 1

i0 = 1e-5
r0 = 0
w0 = 0
s0 = 1 - w0 - i0 - r0

t_discreto = np.linspace(t0,t,1000)

res_SWIR = solve_ivp(swir, (t0, t), y0=[s0, w0, i0, r0], args=( β, ε, δ, γ), t_eval=t_discreto)

#######################
# SEIR

def seir(t, y, β, ε, δ, γ):
    s, e, i, r = y
    dsdt = - β*s*i - δ*s*i
    dedt = δ*s*i - ε*e
    didt = β*s*i + ε*e - γ*i
    drdt = γ*i

    return dsdt, dwdt, didt, drdt

ε  = 0.1 
δ  = 1    
β = 1.5
γ = 1

i0 = 1e-5
r0 = 0
w0 = 0
s0 = 1 - w0 - i0 - r0

t_discreto = np.linspace(t0,t,1000)

res_SEIR = solve_ivp(swir, (t0, t), y0=[s0, w0, i0, r0], args=( β, ε, δ, γ), t_eval=t_discreto)

#######################

fig, ax = plt.subplots(figsize=(15,10))

#ax.plot(res_SMIR.t, res_SMIR.y[0], 'g', label='Suc.SMIR')
#ax.plot(res_SMIR.t, res_SMIR.y[1], 'b', label='Mas.SMIR')
ax.plot(res_SMIR.t, res_SMIR.y[2], 'r', label='Inf.SMIR')
#ax.plot(res_SMIR.t, res_SMIR.y[3], 'k', label='Rec.SMIR')

#ax.plot(res_SIR.t, res_SIR.y[0], '--g', label='Suc.SIR')
ax.plot(res_SIR.t, res_SIR.y[1], '--g', label='Inf.SIR')
#ax.plot(res_SIR.t, res_SIR.y[2], '--k', label='Rec.SIR')

#ax.plot(res_SIRD.t, res_SIRD.y[0], '-g', label='Suc.SIRD')
#ax.plot(res_SIRD.t, res_SIRD.y[1], '--b', label='Inf.SIRD')
#ax.plot(res_SIRD.t, res_SIRD.y[2], '*r', label='Fal.SIRD')
#ax.plot(res_SIRD.t, res_SIRD.y[3], '-k', label='Rec.SIRD')

#ax.plot(res_SWIR.t, res_SWIR.y[0], '-g', label='Suc.SWIR')
#ax.plot(res_SWIR.t, res_SWIR.y[1], '--y', label='Fra.SWIR')
#ax.plot(res_SWIR.t, res_SWIR.y[2], '--k', label='Inf.SWIR')
#ax.plot(res_SWIR.t, res_SWIR.y[3], '-k', label='Rec.SWIR')

#ax.plot(res_SEIR.t, res_SEIR.y[0], '-g', label='Suc.res_SEIR')
#ax.plot(res_SEIR.t, res_SEIR.y[1], '--y', label='Fra.res_SEIR')
#ax.plot(res_SEIR.t, res_SEIR.y[2], 'purple', label='Inf.res_SEIR')
#ax.plot(res_SEIR.t, res_SEIR.y[3], '-k', label='Rec.res_SEIR')

ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.set_xlabel('Dias')
ax.legend(frameon=False)
ax.set_ylim([0,1e-1])

# %%
# SMIR + tanh

def smir(t, y, β, ε, δ):
    s, m, i, r = y
    
    δ = - A*np.tanh(t-t_δ) + M
    ε = - B*np.tanh(t-t_ε) + N
    
    dsdt = - β*s*i - δ*s
    dmdt = δ*s - ε*m*i
    didt = β*s*i + ε*m*i - i
    drdt = i
    return dsdt, dmdt, didt, drdt

δ0 = 0
δ  = 0.1
M = (δ0+δ)/2
A = δ0 - M
t_δ = 15

ε0 = 0
ε  = 1.2
N = (ε0+ε)/2
B = ε0 - N
t_ε = 23

β = 1.5

t0, t = 0, 40
i0 = 1e-5
r0 = 0
m0 = 0
s0 = 1 - m0 - i0 - r0

t_discreto = np.linspace(t0,t,t)

res = solve_ivp(smir, (t0, t), y0=[s0, m0, i0, r0], args=( β, ε, δ), t_eval=t_discreto, method='LSODA')

fig, ax = plt.subplots(figsize=(10,6))
ax.plot(res.t, res.y[0], 'g', label='Sucetíveis')
ax.plot(res.t, res.y[1], 'b', label='Mascarados')
ax.plot(res.t, res.y[2], 'r', label='Infectados')
ax.plot(res.t, res.y[3], 'gray', label='Recuperados')

ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.set_xlabel('Dias')
ax.legend(frameon='False')
#ax.set_ylim([0,1e-1])

# %%
# SMIR + tanh

def smir(t, y, β, ε):
    s, m, i, r = y
    
    δ = - A*np.tanh(t-t_δ) + M
    ε = - B*np.tanh(t-t_ε) + N
    
    dsdt = - β*s*i - δ*s
    dmdt = δ*s - ε*m*i
    didt = β*s*i + ε*m*i - i
    drdt = i
    
    return dsdt, dmdt, didt, drdt


δ0 = 0
δ  = 0.1
M = (δ0+δ)/2
A = δ0 - M
t_δ = 15

ε0 = 0
ε  = 1.0
N = (ε0+ε)/2
B = ε0 - N
t_ε = 23

β = 1.5

t0, t = 0, 40
i0 = 1e-5
r0 = 0
m0 = 0
s0 = 1 - m0 - i0 - r0

t_discreto = np.linspace(t0,t,1000)

res = solve_ivp(smir, (t0, t), y0=[s0, m0, i0, r0], args=( β, ε), t_eval=t_discreto, method='LSODA')

fig, ax = plt.subplots(figsize=(10,6))
ax.plot(res.t, res.y[0], 'g', label='Sucetíveis')
ax.plot(res.t, res.y[1], 'b', label='Mascarados')
ax.plot(res.t, res.y[2], 'r', label='Infectados')
ax.plot(res.t, res.y[3], 'gray', label='Recuperados')

ax.grid(True)
ax.set_ylabel('Densidade populacional')
ax.set_xlabel('Dias')
ax.legend(frameon='False')
ax.set_ylim([0,1e-1])

# %%
# SIRD

def sird(t,y, beta, gamma, delta):
    s, i, d, r = y
    dsdt = -beta*s*i
    didt = beta*s*i - gamma*i - delta*i
    drdt = gamma*i
    dmdt = delta*i
    
    return dsdt, didt, drdt, dmdt

beta  = 1.2
gamma = 0.1
delta = 0.13

t0, t = 0, 100
i0 = 1e-10
r0 = 0
m0 = 0
s0 = 1 - i0 - r0 - m0


resolucao_curva = np.linspace(t0,t,1000)
res = solve_ivp(sird, (t0, t), y0=[s0, i0, r0, m0], args=(beta, gamma, delta), t_eval=resolucao_curva )


fig, ax = plt.subplots(figsize=(10,5))
ax.plot(res.t, res.y[0], label='Sucetível')
ax.plot(res.t, res.y[1], 'r', label='Infectado')
ax.plot(res.t, res.y[2], label='Recuperado')
ax.plot(res.t, res.y[3], 'k', label='Mortos')

ax.grid(True)
ax.set_xlabel('Dias')
ax.set_ylabel('Densidade populacional')
ax.legend(frameon=False)

# %%
# SIRD do Artigo

def sird(t,y, beta, gamma, delta, teta):
    s, i, r, m, I, R, C = y

    mo_t = - C*np.tanh((t - t_nova_variante)) + O
    m_t = (m*(1-v_t)) + (m*(1 - efi)*v_t)*mo_t
    a = - A*np.tanh((t - t_restrição)) + M
    b = - B*np.tanh((t - t_nova_variante)) + N
    
    beta__t = a*b*beta_inicial
    delta__m_t = m_t/(t1+t2)
    gamma__m_t = (1 - m_t)/(t1+t3)
    
    dsdt = -beta__t*s*i
    didt = beta__t*s*i - gamma__m_t*i - delta__m_t*i
    drdt = gamma__m_t*i
    dmdt = delta__m_t*i
    
    I = teta*i
    R = teta*r
    C = I + R + m
        
    return dsdt, didt, drdt, dmdt, I, R, C


beta_inicial = 1.1
teta = 0.2

t1 =   7    # Período de incubação
t2 =   14   # Período entre os primeiros sintomas e a morte.
t3 =   14   # Período entre os primeiros sintomas e a recuperação

v_t =  0.1  # Porcentagem de pessoas vacinadas (porcentagem de indivíduos inicialmente vacinados)
efi =  0.6  # Redução na mortalidade em uma população completamente vacinada
mo_t = 0.5  # Mortalidade durante a Ômicron

mo1 = 1
mo2 = 1         # Variação Mortalidade da nova variante
O = (mo1+mo2)/2
C = mo1 - O

t_restrição = 20
t_nova_variante = 30

a1 = 1
a2 = 0.8         # Medidas restritivas (reduz o beta)
M = (a1+a2)/2
A = a1 - M

b1 = 1
b2 = 6           # Nova variante (aumenta o beta)
N = (b1+b2)/2
B = b1 - N

t0, t = 0, 100
i0 = 1e-10
r0 = 0
m0 = 0
I0 = 0
R0 = 0
C0 = 0

s_rate = 1

s0 = 1 - i0 - r0*(1-s_rate) - m0 - I0 - R0 - C0

resolucao_curva = np.linspace(t0,t,1000)
res = solve_ivp(sird, (t0, t), y0=[s0, i0, r0, m0, I0, R0, C0], args=(beta, gamma, delta, teta), t_eval=resolucao_curva )

fig, ax = plt.subplots(figsize=(15,10), nrows=2)
ax[0].plot(res.t, res.y[0], label='Sucetível')
ax[0].plot(res.t, res.y[1], 'r', label='Infectado')
ax[0].plot(res.t, res.y[2], label='Recuperado')
ax[0].plot(res.t, res.y[3], 'k', label='Mortos')

ax[1].plot(res.t, res.y[4], label='Inf.Notificados')
ax[1].plot(res.t, res.y[5], label='Rec.Notificados')
ax[1].plot(res.t, res.y[6], label='Tot.Notificados')

ax[0].grid(True)
ax[0].set_xlabel('Dias')
ax[0].set_ylabel('Densidade populacional')
ax[0].legend(frameon=False)

ax[1].grid(True)
ax[1].set_xlabel('Dias')
ax[1].set_ylabel('Densidade populacional')
ax[1].legend(frameon=False)
